# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("josaa.csv")

# %%
print(df.dtypes)  
df['avg_rank'] = (df['Opening Rank'] + df['Closing Rank'])//2
df.to_csv('josaa_final_data.csv')
# Out:
# Institute                 object
# Academic Program Name     object
# Quota                     object
# Seat Type                 object
# Gender                    object
# Opening Rank             float64
# Closing Rank             float64
# Year                       int64
# Round                      int64
# dtype: object

# %%
ind = df.index
print(df.dtypes)  
a = np.zeros((1,len(ind)))
for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,7]==2022:
        a[0][i] = 1
        
remove_ind = []
for i  in ind:
    if a[0][i]==0:
        remove_ind.append(i);
# Out:
# Institute                 object
# Academic Program Name     object
# Quota                     object
# Seat Type                 object
# Gender                    object
# Opening Rank             float64
# Closing Rank             float64
# Year                       int64
# Round                      int64
# avg_rank                 float64
# dtype: object

# %%
filtered_df = df[~df.index.isin(remove_ind)]
filtered_df
# Out:
#                                      Institute  \
# 88610  Indian Institute of Technology Guwahati
# 88620  Indian Institute of Technology Guwahati
# 88631  Indian Institute of Technology Guwahati
# 88641  Indian Institute of Technology Guwahati
# 88652  Indian Institute of Technology Guwahati
# 88665  Indian Institute of Technology Guwahati
# 88676  Indian Institute of Technology Guwahati
# 88690  Indian Institute of Technology Guwahati
# 88701  Indian Institute of Technology Guwahati
# 88709  Indian Institute of Technology Guwahati
# 88719  Indian Institute of Technology Guwahati
# 88731  Indian Institute of Technology Guwahati
#
#                                    Academic Program Name Quota Seat Type  \
# 88610  Biosciences and Bioengineering (4 Years, Bache...    AI      OPEN
# 88620  Chemical Engineering (4 Years, Bachelor of Tec...    AI      OPEN
# 88631  Chemical Science and Technology (4 Years, Bach...    AI      OPEN
# ...

# %%
ind = filtered_df.index
l = len(ind)

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Computer Science and Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
        
remove_ind1 = []
for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 

filtered_df_cse = df[~df.index.isin(remove_ind1)]         

filtered_df_cse
# Out:
#                                      Institute  \
# 25420  Indian Institute of Technology Guwahati
# 39683  Indian Institute of Technology Guwahati
# 55619  Indian Institute of Technology Guwahati
# 71840  Indian Institute of Technology Guwahati
# 88652  Indian Institute of Technology Guwahati
#
#                                    Academic Program Name Quota Seat Type  \
# 25420  Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 39683  Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 55619  Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 71840  Computer Science and Engineering (4 Years, Bac...    AI      OPEN
# 88652  Computer Science and Engineering (4 Years, Bac...    AI      OPEN
#
#                                       Gender  Opening Rank  Closing Rank  \
# 25420  Female-only (including Supernumerary)        1002.0        1256.0
# 39683  Female-only (including Supernumerary)        1462.0        1800.0
# ...

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
a2 = np.zeros((1,len(ind)))
a3 = np.zeros((1,len(ind)))
a4 = np.zeros((1,len(ind)))
a5 = np.zeros((1,len(ind)))
a6 = np.zeros((1,len(ind)))
a7 = np.zeros((1,len(ind)))
a8 = np.zeros((1,len(ind)))
a9 = np.zeros((1,len(ind)))
ap = np.zeros((1,len(ind)))
aq = np.zeros((1,len(ind)))

for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electronics and Communication Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Chemical Engineering (4 Years, Bachelor of Technology)":
        a2[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Chemical Science and Technology (4 Years, Bachelor of Technology)":
        a3[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Civil Engineering (4 Years, Bachelor of Technology)":
        a4[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electronics and Electrical Engineering (4 Years, Bachelor of Technology)":
        a5[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering Physics (4 Years, Bachelor of Technology)":
        a6[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mathematics and Computing (4 Years, Bachelor of Technology)":
        a7[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mechanical Engineering (4 Years, Bachelor of Technology)":
        a8[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Data Science and Artificial Intelligence (4 Years, Bachelor of Technology)":
        a9[0][i] = 1   
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Biosciences and Bioengineering (4 Years, Bachelor of Technology)":
        ap[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Guwahati" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Energy Engineering (4 Years, Bachelor of Technology)":
        aq[0][i] = 1                                     
        
remove_ind1 = []
remove_ind2 = []
remove_ind3 = []
remove_ind4 = []
remove_ind5 = []
remove_ind6 = []
remove_ind7 = []
remove_ind8 = []
remove_ind9 = []
remove_indp = []
remove_indq = []


for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 
    if a2[0][i]==0:
        remove_ind2.append(i); 
    if a3[0][i]==0:
        remove_ind3.append(i);         
    if a4[0][i]==0:
        remove_ind4.append(i); 
    if a5[0][i]==0:
        remove_ind5.append(i);     
    if a6[0][i]==0:
        remove_ind6.append(i);     
    if a7[0][i]==0:
        remove_ind7.append(i);     
    if a8[0][i]==0:
        remove_ind8.append(i);     
    if a9[0][i]==0:
        remove_ind9.append(i);     
    if ap[0][i]==0:
        remove_indp.append(i); 
    if aq[0][i]==0:
        remove_indq.append(i);         
        
        
        
filtered_df_ece = df[~df.index.isin(remove_ind1)]
filtered_df_ce = df[~df.index.isin(remove_ind2)]
filtered_df_cst = df[~df.index.isin(remove_ind3)]
filtered_df_civil = df[~df.index.isin(remove_ind4)]
filtered_df_eee = df[~df.index.isin(remove_ind5)]
filtered_df_ep = df[~df.index.isin(remove_ind6)]
filtered_df_mnc = df[~df.index.isin(remove_ind7)]
filtered_df_me = df[~df.index.isin(remove_ind8)]
filtered_df_dsai = df[~df.index.isin(remove_ind9)]
filtered_df_bsbe = df[~df.index.isin(remove_indp)]
filtered_df_energy = df[~df.index.isin(remove_indq)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,15]) #[len, width] of the frame in inches

FS = 14 # fontsize
LW = 2 # linewidth
MS = 10 # markersize
years = ['2018','2019','2020','2021','2022']

ax.plot(years, filtered_df_cse['Opening Rank'], linestyle='-', linewidth=LW, color='red', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CSE')
ax.plot(years, filtered_df_ece['Opening Rank'], linestyle='-', linewidth=LW, color='black', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ECE')
ax.plot(years, filtered_df_ce['Opening Rank'], linestyle='-', linewidth=LW, color='blue', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CHEMICAL')
ax.plot(years, filtered_df_cst['Opening Rank'], linestyle='-', linewidth=LW, color='brown', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CST')
ax.plot(years, filtered_df_civil['Opening Rank'], linestyle='-', linewidth=LW, color='green', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Civil')
ax.plot(years, filtered_df_eee['Opening Rank'], linestyle='-', linewidth=LW, color='magenta', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EEE')
ax.plot(years, filtered_df_ep['Opening Rank'], linestyle='-', linewidth=LW, color='cyan', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EP')
ax.plot(years, filtered_df_mnc['Opening Rank'], linestyle='-', linewidth=LW, color='yellow', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='MNC')
ax.plot(years, filtered_df_me['Opening Rank'], linestyle='-', linewidth=LW, color='orange', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ME')
ax.plot(['2021','2022'], filtered_df_dsai['Opening Rank'], linestyle='-', linewidth=LW, color='darkcyan', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='DSAI')
ax.plot(['2020','2021','2022'], filtered_df_bsbe['Opening Rank'], linestyle='-', linewidth=LW, color='turquoise', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='BSBE')
ax.plot(['2022'], filtered_df_energy['Opening Rank'], linestyle='-', linewidth=LW, color='tomato', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='red', label='ENERGY')

ax.grid(color='gray', linestyle='--', linewidth=.3,alpha=.5)
ax.set_xlabel('Year', fontsize=FS)
# plt.xticks(rotation='vertical')
ax.set_ylabel('Opening Rank of IIT Guwahati of different branches for female category', fontsize=FS)
ax.tick_params(which='both', labelsize=FS) # increase fontsize of xtick and ytick
ax.spines['right'].set_color('none') # turn off right spine
ax.spines['top'].set_color('none') # turn top left spine
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.text(3, 600, 'Increasing trend', fontsize=FS, color='gray')
plt.show()

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
a2 = np.zeros((1,len(ind)))
a3 = np.zeros((1,len(ind)))
a4 = np.zeros((1,len(ind)))
a5 = np.zeros((1,len(ind)))
a6 = np.zeros((1,len(ind)))

for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Bhubaneswar" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Civil Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bhubaneswar" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Computer Science and Engineering (4 Years, Bachelor of Technology)":
        a2[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bhubaneswar" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (4 Years, Bachelor of Technology)":
        a3[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bhubaneswar" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electronics and Communication Engineering (4 Years, Bachelor of Technology)":
        a4[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bhubaneswar" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mechanical Engineering (4 Years, Bachelor of Technology)":
        a5[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bhubaneswar" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Metallurgical and Materials Engineering (4 Years, Bachelor of Technology)":
        a6[0][i] = 1                               
        
remove_ind1 = []
remove_ind2 = []
remove_ind3 = []
remove_ind4 = []
remove_ind5 = []
remove_ind6 = []


for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 
    if a2[0][i]==0:
        remove_ind2.append(i); 
    if a3[0][i]==0:
        remove_ind3.append(i);         
    if a4[0][i]==0:
        remove_ind4.append(i); 
    if a5[0][i]==0:
        remove_ind5.append(i);     
    if a6[0][i]==0:
        remove_ind6.append(i);         
        
        
        
filtered_df_civil = df[~df.index.isin(remove_ind1)]
filtered_df_cse = df[~df.index.isin(remove_ind2)]
filtered_df_ee = df[~df.index.isin(remove_ind3)]
filtered_df_ece = df[~df.index.isin(remove_ind4)]
filtered_df_me = df[~df.index.isin(remove_ind5)]
filtered_df_metallurgical = df[~df.index.isin(remove_ind6)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,15]) #[len, width] of the frame in inches

FS = 14 # fontsize
LW = 2 # linewidth
MS = 10 # markersize

years = ['2018','2019','2020','2021','2022']

# ax.plot(years, filtered_df_civil['Opening Rank'], linestyle='-', linewidth=LW, color='green', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Civil')
ax.plot(years, filtered_df_cse['Opening Rank'], linestyle='-', linewidth=LW, color='red', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CSE')
ax.plot(years, filtered_df_ee['Opening Rank'], linestyle='-', linewidth=LW, color='magenta', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EEE')
ax.plot(years, filtered_df_ece['Opening Rank'], linestyle='-', linewidth=LW, color='black', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ECE')
ax.plot(years, filtered_df_me['Opening Rank'], linestyle='-', linewidth=LW, color='orange', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ME')
ax.plot(years, filtered_df_metallurgical['Opening Rank'], linestyle='-', linewidth=LW, color='tomato', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Metallurgical and Materials Engineering (4 Years, Bachelor of Technology)')

ax.grid(color='gray', linestyle='--', linewidth=.3,alpha=.5)
ax.set_xlabel('Year', fontsize=FS)
# plt.xticks(rotation='vertical')
ax.set_ylabel('Opening Rank of IIT Bhubaneswar of different branches for female category', fontsize=FS)
ax.tick_params(which='both', labelsize=FS) # increase fontsize of xtick and ytick
ax.spines['right'].set_color('none') # turn off right spine
ax.spines['top'].set_color('none') # turn top left spine
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.text(3, 600, 'Increasing trend', fontsize=FS, color='gray')
plt.show()

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
a2 = np.zeros((1,len(ind)))
a3 = np.zeros((1,len(ind)))
a4 = np.zeros((1,len(ind)))
a5 = np.zeros((1,len(ind)))
a6 = np.zeros((1,len(ind)))
a7 = np.zeros((1,len(ind)))
a8 = np.zeros((1,len(ind)))
a9 = np.zeros((1,len(ind)))
ap = np.zeros((1,len(ind)))
aq = np.zeros((1,len(ind)))
ar = np.zeros((1,len(ind)))

for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Aerospace Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Chemical Engineering (4 Years, Bachelor of Technology)":
        a2[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Computer Science and Engineering (4 Years, Bachelor of Technology)":
        a3[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Civil Engineering (4 Years, Bachelor of Technology)":
        a4[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (4 Years, Bachelor of Technology)":
        a5[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering Physics (4 Years, Bachelor of Technology)":
        a6[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Metallurgical Engineering and Materials Science (4 Years, Bachelor of Technology)":
        a7[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mechanical Engineering (4 Years, Bachelor of Technology)":
        a8[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Chemistry (4 Years, Bachelor of Science)":
        a9[0][i] = 1   
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Economics (4 Years, Bachelor of Science)":
        ap[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Energy Engineering (4 Years, Bachelor of Technology)":
        aq[0][i] = 1  
    if df.iloc[i,0]=="Indian Institute of Technology Bombay" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="BS in Mathematics (4 Years, Bachelor of Science)":
        ar[0][i] = 1                                         
        
remove_ind1 = []
remove_ind2 = []
remove_ind3 = []
remove_ind4 = []
remove_ind5 = []
remove_ind6 = []
remove_ind7 = []
remove_ind8 = []
remove_ind9 = []
remove_indp = []
remove_indq = []
remove_indr = []


for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 
    if a2[0][i]==0:
        remove_ind2.append(i); 
    if a3[0][i]==0:
        remove_ind3.append(i);         
    if a4[0][i]==0:
        remove_ind4.append(i); 
    if a5[0][i]==0:
        remove_ind5.append(i);     
    if a6[0][i]==0:
        remove_ind6.append(i);     
    if a7[0][i]==0:
        remove_ind7.append(i);     
    if a8[0][i]==0:
        remove_ind8.append(i);     
    if a9[0][i]==0:
        remove_ind9.append(i);     
    if ap[0][i]==0:
        remove_indp.append(i); 
    if aq[0][i]==0:
        remove_indq.append(i);     
    if ar[0][i]==0:
        remove_indr.append(i);          
        
        
        
filtered_df_aero = df[~df.index.isin(remove_ind1)]
filtered_df_ce = df[~df.index.isin(remove_ind2)]
filtered_df_cse = df[~df.index.isin(remove_ind3)]
filtered_df_civil = df[~df.index.isin(remove_ind4)]
filtered_df_ee = df[~df.index.isin(remove_ind5)]
filtered_df_ep = df[~df.index.isin(remove_ind6)]
filtered_df_metallurgical = df[~df.index.isin(remove_ind7)]
filtered_df_me = df[~df.index.isin(remove_ind8)]
filtered_df_chemistry = df[~df.index.isin(remove_ind9)]
filtered_df_echonomics = df[~df.index.isin(remove_indp)]
filtered_df_energy = df[~df.index.isin(remove_indq)]
filtered_df_bs_in_math = df[~df.index.isin(remove_indr)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,15]) #[len, width] of the frame in inches

FS = 14 # fontsize
LW = 2 # linewidth
MS = 10 # markersize
years = ['2018','2019','2020','2021','2022']

ax.plot(years, filtered_df_aero['Opening Rank'], linestyle='-', linewidth=LW, color='red', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Aerospace Engineering (4 Years, Bachelor of Technology)')
ax.plot(years, filtered_df_ce['Opening Rank'], linestyle='-', linewidth=LW, color='black', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CE')
ax.plot(years, filtered_df_cse['Opening Rank'], linestyle='-', linewidth=LW, color='blue', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CSE')
ax.plot(years, filtered_df_civil['Opening Rank'], linestyle='-', linewidth=LW, color='brown', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Civil')
ax.plot(years, filtered_df_ee['Opening Rank'], linestyle='-', linewidth=LW, color='green', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EE')
ax.plot(years, filtered_df_ep['Opening Rank'], linestyle='-', linewidth=LW, color='magenta', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EP')
ax.plot(years, filtered_df_metallurgical['Opening Rank'], linestyle='-', linewidth=LW, color='cyan', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Metallurgical Engineering and Materials Science (4 Years, Bachelor of Technology)')
ax.plot(years, filtered_df_me['Opening Rank'], linestyle='-', linewidth=LW, color='yellow', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ME')
ax.plot(years, filtered_df_chemistry['Opening Rank'], linestyle='-', linewidth=LW, color='orange', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Chemistry')
ax.plot(years, filtered_df_echonomics['Opening Rank'], linestyle='-', linewidth=LW, color='darkcyan', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Echonomics')
ax.plot(['2022'], filtered_df_energy['Opening Rank'], linestyle='-', linewidth=LW, color='turquoise', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Energy')
ax.plot(years, filtered_df_bs_in_math['Opening Rank'], linestyle='-', linewidth=LW, color='tomato', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='red', label='BS in Mathematics')

ax.grid(color='gray', linestyle='--', linewidth=.3,alpha=.5)
ax.set_xlabel('Year', fontsize=FS)
# plt.xticks(rotation='vertical')
ax.set_ylabel('Opening Rank of IIT Bombay of different branches for female category', fontsize=FS)
ax.tick_params(which='both', labelsize=FS) # increase fontsize of xtick and ytick
ax.spines['right'].set_color('none') # turn off right spine
ax.spines['top'].set_color('none') # turn top left spine
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.text(3, 600, 'Increasing trend', fontsize=FS, color='gray')
plt.show()

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
a2 = np.zeros((1,len(ind)))
a3 = np.zeros((1,len(ind)))
a4 = np.zeros((1,len(ind)))
a5 = np.zeros((1,len(ind)))
a6 = np.zeros((1,len(ind)))
a7 = np.zeros((1,len(ind)))
a8 = np.zeros((1,len(ind)))
a9 = np.zeros((1,len(ind)))
ap = np.zeros((1,len(ind)))
aq = np.zeros((1,len(ind)))
ar = np.zeros((1,len(ind)))

for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Mandi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mechanical Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Mandi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Data Science and Engineering (4 Years, Bachelor of Technology)":
        a2[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Mandi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Computer Science and Engineering (4 Years, Bachelor of Technology)":
        a3[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Mandi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Civil Engineering (4 Years, Bachelor of Technology)":
        a4[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Mandi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (4 Years, Bachelor of Technology)":
        a5[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Mandi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering Physics (4 Years, Bachelor of Technology)":
        a6[0][i] = 1
                                       
        
remove_ind1 = []
remove_ind2 = []
remove_ind3 = []
remove_ind4 = []
remove_ind5 = []
remove_ind6 = []


for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 
    if a2[0][i]==0:
        remove_ind2.append(i); 
    if a3[0][i]==0:
        remove_ind3.append(i);         
    if a4[0][i]==0:
        remove_ind4.append(i); 
    if a5[0][i]==0:
        remove_ind5.append(i);     
    if a6[0][i]==0:
        remove_ind6.append(i);            
        
        
        
filtered_df_me = df[~df.index.isin(remove_ind1)]
filtered_df_ds = df[~df.index.isin(remove_ind2)]
filtered_df_cse = df[~df.index.isin(remove_ind3)]
filtered_df_civil = df[~df.index.isin(remove_ind4)]
filtered_df_ee = df[~df.index.isin(remove_ind5)]
filtered_df_ep = df[~df.index.isin(remove_ind6)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,15]) #[len, width] of the frame in inches

FS = 14 # fontsize
LW = 2 # linewidth
MS = 10 # markersize
years = ['2018','2019','2020','2021','2022']

ax.plot(years, filtered_df_aero['Opening Rank'], linestyle='-', linewidth=LW, color='red', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Mechanical Engineering (4 Years, Bachelor of Technology)')
ax.plot(years, filtered_df_ce['Opening Rank'], linestyle='-', linewidth=LW, color='black', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Data Science and Engineering (4 Years, Bachelor of Technology)')
ax.plot(years, filtered_df_cse['Opening Rank'], linestyle='-', linewidth=LW, color='blue', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CSE')
ax.plot(years, filtered_df_civil['Opening Rank'], linestyle='-', linewidth=LW, color='brown', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Civil')
ax.plot(years, filtered_df_ee['Opening Rank'], linestyle='-', linewidth=LW, color='green', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EE')
ax.plot(['2019','2020','2021','2022'], filtered_df_ep['Opening Rank'], linestyle='-', linewidth=LW, color='magenta', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EP')

ax.grid(color='gray', linestyle='--', linewidth=.3,alpha=.5)
ax.set_xlabel('Year', fontsize=FS)
# plt.xticks(rotation='vertical')
ax.set_ylabel('Opening Rank of IIT Mandi of different branches for female category', fontsize=FS)
ax.tick_params(which='both', labelsize=FS) # increase fontsize of xtick and ytick
ax.spines['right'].set_color('none') # turn off right spine
ax.spines['top'].set_color('none') # turn top left spine
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.text(3, 600, 'Increasing trend', fontsize=FS, color='gray')
plt.show()

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
a2 = np.zeros((1,len(ind)))
a3 = np.zeros((1,len(ind)))
a4 = np.zeros((1,len(ind)))
a5 = np.zeros((1,len(ind)))
a6 = np.zeros((1,len(ind)))
a7 = np.zeros((1,len(ind)))
a8 = np.zeros((1,len(ind)))
a9 = np.zeros((1,len(ind)))
ap = np.zeros((1,len(ind)))
aq = np.zeros((1,len(ind)))
ar = np.zeros((1,len(ind)))
at = np.zeros((1,len(ind)))
au = np.zeros((1,len(ind)))

        
remove_ind1 = []
remove_ind2 = []
remove_ind3 = []
remove_ind4 = []
remove_ind5 = []
remove_ind6 = []
remove_ind7 = []
remove_ind8 = []
remove_ind9 = []
remove_indp = []
remove_indq = []
remove_indr = []
remove_indt = []
remove_indu = []

for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Biotechnology and Biochemical Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Chemical Engineering (4 Years, Bachelor of Technology)":
        a2[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Computer Science and Engineering (4 Years, Bachelor of Technology)":
        a3[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Civil Engineering (4 Years, Bachelor of Technology)":
        a4[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (4 Years, Bachelor of Technology)":
        a5[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering Physics (4 Years, Bachelor of Technology)":
        a6[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Materials Engineering (4 Years, Bachelor of Technology)":
        a7[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mechanical Engineering (4 Years, Bachelor of Technology)":
        a8[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering and Computational Mechanics (4 Years, Bachelor of Technology)":
        a9[0][i] = 1   
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Textile Technology (4 Years, Bachelor of Technology)":
        ap[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Energy Engineering (4 Years, Bachelor of Technology)":
        aq[0][i] = 1  
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Production and Industrial Engineering (4 Years, Bachelor of Technology)":
        ar[0][i] = 1    
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mathematics and Computing (4 Years, Bachelor of Technology)":
        at[0][i] = 1 
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (Power and Automation) (4 Years, Bachelor of Technology)":
        au[0][i] = 1                                              

for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 
    if a2[0][i]==0:
        remove_ind2.append(i); 
    if a3[0][i]==0:
        remove_ind3.append(i);         
    if a4[0][i]==0:
        remove_ind4.append(i); 
    if a5[0][i]==0:
        remove_ind5.append(i);     
    if a6[0][i]==0:
        remove_ind6.append(i);     
    if a7[0][i]==0:
        remove_ind7.append(i);     
    if a8[0][i]==0:
        remove_ind8.append(i);     
    if a9[0][i]==0:
        remove_ind9.append(i);     
    if ap[0][i]==0:
        remove_indp.append(i); 
    if aq[0][i]==0:
        remove_indq.append(i);     
    if ar[0][i]==0:
        remove_indr.append(i);   
    if at[0][i]==0:
        remove_indt.append(i); 
    if au[0][i]==0:
        remove_indu.append(i);

# %%
filtered_df_btbe = df[~df.index.isin(remove_ind1)]
filtered_df_ce = df[~df.index.isin(remove_ind2)]
filtered_df_cse = df[~df.index.isin(remove_ind3)]
filtered_df_civil = df[~df.index.isin(remove_ind4)]
filtered_df_ee = df[~df.index.isin(remove_ind5)]
filtered_df_ep = df[~df.index.isin(remove_ind6)]
filtered_df_materials = df[~df.index.isin(remove_ind7)]
filtered_df_me = df[~df.index.isin(remove_ind8)]
filtered_df_cm = df[~df.index.isin(remove_ind9)]
filtered_df_textile = df[~df.index.isin(remove_indp)]
filtered_df_energy = df[~df.index.isin(remove_indq)]
filtered_df_production = df[~df.index.isin(remove_indr)]
filtered_df_mnc = df[~df.index.isin(remove_indt)]
filtered_df_automation = df[~df.index.isin(remove_indu)]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,15]) #[len, width] of the frame in inches

FS = 14 # fontsize
LW = 2 # linewidth
MS = 10 # markersize
years = ['2018','2019','2020','2021','2022']

ax.plot(years, filtered_df_btbe['Opening Rank'], linestyle='-', linewidth=LW, color='red', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CSE')
ax.plot(years, filtered_df_ce['Opening Rank'], linestyle='-', linewidth=LW, color='black', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ECE')
ax.plot(years, filtered_df_cse['Opening Rank'], linestyle='-', linewidth=LW, color='blue', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CHEMICAL')
ax.plot(years, filtered_df_civil['Opening Rank'], linestyle='-', linewidth=LW, color='brown', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='CST')
ax.plot(years, filtered_df_ee['Opening Rank'], linestyle='-', linewidth=LW, color='green', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='Civil')
ax.plot(years, filtered_df_ep['Opening Rank'], linestyle='-', linewidth=LW, color='magenta', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EEE')
ax.plot(['2020','2021','2022'], filtered_df_materials['Opening Rank'], linestyle='-', linewidth=LW, color='cyan', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='EP')
ax.plot(years, filtered_df_me['Opening Rank'], linestyle='-', linewidth=LW, color='yellow', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='MNC')
ax.plot(['2020','2021','2022'], filtered_df_cm['Opening Rank'], linestyle='-', linewidth=LW, color='orange', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='ME')
ax.plot(years, filtered_df_textile['Opening Rank'], linestyle='-', linewidth=LW, color='darkcyan', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='DSAI')
ax.plot(['2021','2022'], filtered_df_energy['Opening Rank'], linestyle='-', linewidth=LW, color='turquoise', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='BSBE')
ax.plot(years, filtered_df_production['Opening Rank'], linestyle='-', linewidth=LW, color='tomato', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='red', label='ENERGY')
ax.plot(years, filtered_df_mnc['Opening Rank'], linestyle='-', linewidth=LW, color='chocolate', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='gray', label='BSBE')
ax.plot(years, filtered_df_automation['Opening Rank'], linestyle='-', linewidth=LW, color='skyblue', marker='o', markersize=MS, markeredgecolor='blue', markerfacecolor='red', label='ENERGY')

ax.grid(color='gray', linestyle='--', linewidth=.3,alpha=.5)
ax.set_xlabel('Year', fontsize=FS)
# plt.xticks(rotation='vertical')
ax.set_ylabel('Opening Rank of IIT Delhi of different branches for female category', fontsize=FS)
ax.tick_params(which='both', labelsize=FS) # increase fontsize of xtick and ytick
ax.spines['right'].set_color('none') # turn off right spine
ax.spines['top'].set_color('none') # turn top left spine
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# ax.text(3, 600, 'Increasing trend', fontsize=FS, color='gray')
plt.show()

# %%
ind = df.index  
a1 = np.zeros((1,len(ind)))
a2 = np.zeros((1,len(ind)))
a3 = np.zeros((1,len(ind)))
a4 = np.zeros((1,len(ind)))
a5 = np.zeros((1,len(ind)))
a6 = np.zeros((1,len(ind)))
a7 = np.zeros((1,len(ind)))
a8 = np.zeros((1,len(ind)))
a9 = np.zeros((1,len(ind)))
ap = np.zeros((1,len(ind)))
aq = np.zeros((1,len(ind)))
ar = np.zeros((1,len(ind)))
at = np.zeros((1,len(ind)))
au = np.zeros((1,len(ind)))

        
remove_ind1 = []
remove_ind2 = []
remove_ind3 = []
remove_ind4 = []
remove_ind5 = []
remove_ind6 = []
remove_ind7 = []
remove_ind8 = []
remove_ind9 = []
remove_indp = []
remove_indq = []
remove_indr = []
remove_indt = []
remove_indu = []

for i in ind:
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Biotechnology and Biochemical Engineering (4 Years, Bachelor of Technology)":
        a1[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Chemical Engineering (4 Years, Bachelor of Technology)":
        a2[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Computer Science and Engineering (4 Years, Bachelor of Technology)":
        a3[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Civil Engineering (4 Years, Bachelor of Technology)":
        a4[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (4 Years, Bachelor of Technology)":
        a5[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering Physics (4 Years, Bachelor of Technology)":
        a6[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Materials Engineering (4 Years, Bachelor of Technology)":
        a7[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mechanical Engineering (4 Years, Bachelor of Technology)":
        a8[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Engineering and Computational Mechanics (4 Years, Bachelor of Technology)":
        a9[0][i] = 1   
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Textile Technology (4 Years, Bachelor of Technology)":
        ap[0][i] = 1
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Energy Engineering (4 Years, Bachelor of Technology)":
        aq[0][i] = 1  
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Production and Industrial Engineering (4 Years, Bachelor of Technology)":
        ar[0][i] = 1    
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Mathematics and Computing (4 Years, Bachelor of Technology)":
        at[0][i] = 1 
    if df.iloc[i,0]=="Indian Institute of Technology Delhi" and df.iloc[i,4]=="Female-only (including Supernumerary)" and df.iloc[i,3]=="OPEN" and df.iloc[i,8]==6 and df.iloc[i,1]=="Electrical Engineering (Power and Automation) (4 Years, Bachelor of Technology)":
        au[0][i] = 1                                              

for i  in ind:
    if a1[0][i]==0:
        remove_ind1.append(i); 
    if a2[0][i]==0:
        remove_ind2.append(i); 
    if a3[0][i]==0:
        remove_ind3.append(i);         
    if a4[0][i]==0:
        remove_ind4.append(i); 
    if a5[0][i]==0:
        remove_ind5.append(i);     
    if a6[0][i]==0:
        remove_ind6.append(i);     
    if a7[0][i]==0:
        remove_ind7.append(i);     
    if a8[0][i]==0:
        remove_ind8.append(i);     
    if a9[0][i]==0:
        remove_ind9.append(i);     
    if ap[0][i]==0:
        remove_indp.append(i); 
    if aq[0][i]==0:
        remove_indq.append(i);     
    if ar[0][i]==0:
        remove_indr.append(i);   
    if at[0][i]==0:
        remove_indt.append(i); 
    if au[0][i]==0:
        remove_indu.append(i);
